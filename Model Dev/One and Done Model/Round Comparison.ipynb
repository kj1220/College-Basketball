# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('matchups_2010.csv')
print(df.shape)
df.head()
# Out:
# (880, 46)
#    year   region         round  high_bracket_seed  high_bracket_team  \
# 0  2010  Midwest   First Round                  1        2010 Kansas
# 1  2010  Midwest  Second Round                  1        2010 Kansas
# 2  2010  Midwest   First Round                  8          2010 UNLV
# 3  2010  Midwest   First Round                  5  2010 Michigan St.
# 4  2010  Midwest  Second Round                  5  2010 Michigan St.
#
#    low_bracket_seed     low_bracket_team  win        wab  prpg!  ...  2p%d  \
# 0                16          2010 Lehigh    1  18.314194    6.5  ...  -8.0
# 1                 9   2010 Northern Iowa    0   7.806784    0.0  ...  -7.7
# 2                 9   2010 Northern Iowa    0  -2.872254   -6.2  ...  -4.4
# 3                12  2010 New Mexico St.    1   5.694640   -0.5  ...  -6.4
# 4                 4        2010 Maryland    1   0.185986   -5.6  ...  -4.6
#
#    3p%d  blk%  ast%d  3prd  ft%d  height  size  experience  bench
# ...

# %%
sns.boxplot(x='wab', y='round', data=df)
# Out:
# <Axes: xlabel='wab', ylabel='round'>

# %%
sns.boxplot(x='prpg!', y='round', data=df)
# Out:
# <Axes: xlabel='prpg!', ylabel='round'>

# %%
sns.boxplot(x='bpm', y='round', data=df)
# Out:
# <Axes: xlabel='bpm', ylabel='round'>

# %%
sns.boxplot(x='kenpom_adjem', y='round', data=df)
# Out:
# <Axes: xlabel='kenpom_adjem', ylabel='round'>

# %%
sns.boxplot(x='barthag', y='round', data=df)
# Out:
# <Axes: xlabel='barthag', ylabel='round'>
