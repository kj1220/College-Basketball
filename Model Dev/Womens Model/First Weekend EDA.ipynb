# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
import statsmodels.api as sm
from itertools import combinations

#df = pd.read_csv('matchups_women_first_weekend.csv')
df = pd.read_csv('matchups_womens_first_weekend.csv')
print(df.shape)
df.head()
# Out:
# (336, 49)
#     game_id  year        round region        high_team_id     low_team_id  \
# 0  20171101  2017  First Round   East    2017 Connecticut     2017 Albany
# 1  20171108  2017  First Round   East       2017 Syracuse   2017 Iowa St.
# 2  20171106  2017  First Round   East      2017 Texas A&M       2017 Penn
# 3  20171104  2017  First Round   East           2017 UCLA  2017 Boise St.
# 4  20171103  2017  First Round   East  2017 West Virginia       2017 Elon
#
#    win   ppg  opp_ppg  net_ppg  ...   3prd  %pts_ftd  %pts_2pd  %pts_3pd  \
# 0    1  31.1     -0.6     30.6  ...  0.081     0.050     0.040     0.090
# 1    1  27.5    -21.2      6.3  ... -0.044     0.016     0.043     0.027
# 2    1   1.1     -3.4     -2.3  ... -0.061     0.007     0.094     0.088
# 3    1  17.8    -11.7      6.2  ... -0.037     0.043     0.012     0.032
# 4    1  13.4    -12.4      0.9  ...  0.003     0.012     0.023     0.012
#
#    astd%  tovd%  opp_ast_tov  opp_stl%  opp_blk%  opp_pf%
# 0 -0.117 -0.011        -0.18    -0.048    -0.051   -0.029
# 1  0.080  0.103        -0.47    -0.002     0.000    0.010
# 2 -0.059  0.022        -0.19    -0.012    -0.070    0.050
# 3 -0.024  0.035        -0.29    -0.022    -0.027   -0.007
# 4 -0.051  0.017        -0.24     0.000    -0.032   -0.014
#
# [5 rows x 49 columns]

# %%
df['win'].value_counts(normalize=True)
# Out:
# 1    0.720238
# 0    0.279762
# Name: win, dtype: float64

# %%
split_df = df.drop(['game_id', 'year', 'round', 'region', 'high_team_id', 'low_team_id'],axis=1)
print(split_df.shape)
split_df.head()
# Out:
# (336, 43)
#    win   ppg  opp_ppg  net_ppg  off_rtg  def_rtg  net_rtg  pace  hhs_net_rtg  \
# 0    1  31.1     -0.6     30.6     90.9    -47.4     43.6  -0.8         54.9
# 1    1  27.5    -21.2      6.3     81.7    -73.9      7.8   4.2          7.6
# 2    1   1.1     -3.4     -2.3     66.6    -70.9     -4.2   4.9          6.2
# 3    1  17.8    -11.7      6.2     72.4    -63.3      9.0   1.7         20.2
# 4    1  13.4    -12.4      0.9     67.3    -65.1      2.2   2.8          6.8
#
#    hhs_off_rtg  ...   3prd  %pts_ftd  %pts_2pd  %pts_3pd  astd%  tovd%  \
# 0         98.0  ...  0.081     0.050     0.040     0.090 -0.117 -0.011
# 1         79.5  ... -0.044     0.016     0.043     0.027  0.080  0.103
# 2         73.3  ... -0.061     0.007     0.094     0.088 -0.059  0.022
# 3         79.5  ... -0.037     0.043     0.012     0.032 -0.024  0.035
# 4         71.9  ...  0.003     0.012     0.023     0.012 -0.051  0.017
#
#    opp_ast_tov  opp_stl%  opp_blk%  opp_pf%
# 0        -0.18    -0.048    -0.051   -0.029
# 1        -0.47    -0.002     0.000    0.010
# 2        -0.19    -0.012    -0.070    0.050
# 3        -0.29    -0.022    -0.027   -0.007
# 4        -0.24     0.000    -0.032   -0.014
#
# [5 rows x 43 columns]

# %%
split_df.columns
# Out:
# Index(['win', 'ppg', 'opp_ppg', 'net_ppg', 'off_rtg', 'def_rtg', 'net_rtg',
#        'pace', 'hhs_net_rtg', 'hhs_off_rtg', 'hhs_def_rtg', 'rpi', 'ppp',
#        'ppsa', 'efg%', 'ftr', '3pr', '%pts_ft', '%pts_2p', '%pts_3p', 'orb%',
#        'drb%', 'trb%', 'ast%', 'tov%', 'ast_tov', 'stl%', 'blk%', 'pf%',
#        'pppd', 'opp_ppsa', 'efgd%', 'ftrd', '3prd', '%pts_ftd', '%pts_2pd',
#        '%pts_3pd', 'astd%', 'tovd%', 'opp_ast_tov', 'opp_stl%', 'opp_blk%',
#        'opp_pf%'],
#       dtype='object')

# %%
X = split_df.drop('win', axis=1)
X = split_df[['ppg', 'opp_ppg', 'net_ppg', 'off_rtg', 'def_rtg', 'net_rtg',
       'pace', 'hhs_net_rtg', 'hhs_off_rtg', 'hhs_def_rtg', 'rpi', 'ppp',
       'ppsa', 'efg%', 'ftr', '3pr', '%pts_ft', '%pts_2p', '%pts_3p', 'orb%',
       'drb%', 'trb%', 'ast%', 'tov%', 'ast_tov', 'stl%', 'blk%', 'pf%',
       'pppd', 'opp_ppsa', 'efgd%', 'ftrd', '3prd', '%pts_ftd', '%pts_2pd',
       '%pts_3pd', 'astd%', 'tovd%', 'opp_ast_tov', 'opp_stl%', 'opp_blk%',
       'opp_pf%']]
Y = df['win']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

print(train_df.shape)
print(test_df.shape)
# Out:
# (235, 43)
# (101, 43)

# %% [markdown]
# ## I. Filter Methods

# %% [markdown]
# ### A. Box Plots

# %% [raw]
# scaler = MinMaxScaler(feature_range=(0,100))
# box_df = train_df
# numeric_columns = train_df.drop(columns=['win']).columns
# box_df[numeric_columns] = scaler.fit_transform(box_df[numeric_columns])
#
# for column in box_df.columns:
#     fig, axes = plt.subplots(1, 2, figsize=(4, 3), sharey=True)
#
#     # Histogram on the left
#     sns.histplot(box_df[column], kde=True, ax=axes[0], color='skyblue', bins=30)
#     axes[0].set_title(f'Histogram of {column}')
#     axes[0].set_xlabel(column)
#
#     # Box plot on the right
#     sns.boxplot(x='win', y=column, data=box_df, ax=axes[1], color='salmon')
#     axes[1].set_title(f'Box Plot of {column}')
#     axes[1].set_xlabel(column)
#
#     # Adjust layout and show the plots
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# ### B. Correlation

# %%
corr_matrix = train_df.corr()
correlation_with_target = round(abs(corr_matrix['win'])*100,2)
correlation_with_target = correlation_with_target[correlation_with_target >= 10]
print(correlation_with_target)
# Out:
# ppg             15.65
# opp_ppg         28.20
# net_ppg         40.45
# off_rtg         19.30
# def_rtg         35.13
# net_rtg         39.70
# pace            12.16
# hhs_net_rtg     56.10
# hhs_off_rtg     45.70
# hhs_def_rtg     51.54
# rpi             59.75
# ppp             12.85
# ppsa            14.03
# efg%            12.44
# ftr             22.00
# 3pr             20.00
# %pts_3p         15.91
# trb%            34.15
# ast%            12.33
# tov%            17.12
# ast_tov         14.89
# stl%            14.32
# blk%            16.49
# pppd            32.20
# opp_ppsa        32.44
# efgd%           31.93
# ftrd            11.80
# tovd%           15.27
# opp_ast_tov     17.92
# opp_pf%         10.18
# win            100.00
# Name: win, dtype: float64

# %% [markdown]
# ### C. Statistical Tests

# %%
X = train_df[['ppg', 'opp_ppg', 'net_ppg', 'off_rtg', 'def_rtg', 'net_rtg',
       'pace', 'hhs_net_rtg', 'hhs_off_rtg', 'hhs_def_rtg', 'rpi', 'ppp',
       'ppsa', 'efg%', 'ftr', '3pr', '%pts_ft', '%pts_2p', '%pts_3p', 'orb%',
       'drb%', 'trb%', 'ast%', 'tov%', 'ast_tov', 'stl%', 'blk%', 'pf%',
       'pppd', 'opp_ppsa', 'efgd%', 'ftrd', '3prd', '%pts_ftd', '%pts_2pd',
       '%pts_3pd', 'astd%', 'tovd%', 'opp_ast_tov', 'opp_stl%', 'opp_blk%',
       'opp_pf%']]
#X = train_df.drop('win', axis=1)
y = train_df['win']

# ANOVA
f_values, p_values = f_classif(X, y)
# Mutual Information
mi = mutual_info_regression(X, y)

column_names = np.array(X.columns)
stats_df = pd.DataFrame({
    'feature': column_names,
    'f_values': f_values,
    'p_values': p_values,
    'mutual_info': mi
})
stats_df
#stats_df.to_csv('stats.csv')
# Out:
#         feature    f_values      p_values  mutual_info
# 0           ppg    5.851772  1.632865e-02     0.014406
# 1       opp_ppg   20.136089  1.133581e-05     0.033082
# 2       net_ppg   45.572335  1.157757e-10     0.089978
# 3       off_rtg    9.010296  2.976932e-03     0.009751
# 4       def_rtg   32.793562  3.143704e-08     0.060184
# 5       net_rtg   43.605349  2.690247e-10     0.109977
# 6          pace    3.498545  6.267654e-02     0.000000
# 7   hhs_net_rtg  107.005122  6.979264e-21     0.245777
# 8   hhs_off_rtg   61.517352  1.572748e-13     0.119482
# 9   hhs_def_rtg   84.269756  2.405636e-17     0.191677
# 10          rpi  129.354262  3.945765e-24     0.223487
# 11          ppp    3.911691  4.912973e-02     0.011653
# 12         ppsa    4.679716  3.153819e-02     0.015035
# 13         efg%    3.661007  5.692555e-02     0.028035
# 14          ftr   11.850251  6.833223e-04     0.000766
# 15          3pr    9.709723  2.063094e-03     0.055318
# 16      %pts_ft    0.093309  7.602849e-01     0.016510
# 17      %pts_2p    0.872902  3.511203e-01     0.000000
# 18      %pts_3p    6.048711  1.464436e-02     0.000000
# 19         orb%    0.032656  8.567531e-01     0.000000
# 20         drb%    0.345870  5.570302e-01     0.002396
# 21         trb%   30.761386  7.892812e-08     0.086209
# 22         ast%    3.595302  5.918036e-02     0.000000
# 23         tov%    7.037189  8.532347e-03     0.005520
# 24      ast_tov    5.282141  2.243175e-02     0.033665
# 25         stl%    4.879071  2.815820e-02     0.025383
# 26         blk%    6.516632  1.132610e-02     0.024187
# 27          pf%    1.625093  2.036529e-01     0.015358
# 28         pppd   26.944237  4.557127e-07     0.059229
# 29     opp_ppsa   27.400928  3.688404e-07     0.063624
# 30        efgd%   26.450702  5.730475e-07     0.055144
# 31         ftrd    3.288480  7.105418e-02     0.048761
# 32         3prd    0.772191  3.804453e-01     0.037776
# 33     %pts_ftd    0.140245  7.083779e-01     0.000000
# 34     %pts_2pd    0.047510  8.276449e-01     0.033800
# 35     %pts_3pd    1.206213  2.732171e-01     0.000000
# 36        astd%    1.573301  2.109852e-01     0.000000
# 37        tovd%    5.564029  1.915981e-02     0.029494
# 38  opp_ast_tov    7.728616  5.879236e-03     0.010368
# 39     opp_stl%    2.164315  1.425968e-01     0.006480
# 40     opp_blk%    1.770139  1.846656e-01     0.028108
# 41      opp_pf%    2.441158  1.195461e-01     0.000000

# %%
feature_df = stats_df[stats_df['mutual_info'] > 0]
feature_df
# Out:
#         feature    f_values      p_values  mutual_info
# 0           ppg    5.851772  1.632865e-02     0.014406
# 1       opp_ppg   20.136089  1.133581e-05     0.033082
# 2       net_ppg   45.572335  1.157757e-10     0.089978
# 3       off_rtg    9.010296  2.976932e-03     0.009751
# 4       def_rtg   32.793562  3.143704e-08     0.060184
# 5       net_rtg   43.605349  2.690247e-10     0.109977
# 7   hhs_net_rtg  107.005122  6.979264e-21     0.245777
# 8   hhs_off_rtg   61.517352  1.572748e-13     0.119482
# 9   hhs_def_rtg   84.269756  2.405636e-17     0.191677
# 10          rpi  129.354262  3.945765e-24     0.223487
# 11          ppp    3.911691  4.912973e-02     0.011653
# 12         ppsa    4.679716  3.153819e-02     0.015035
# 13         efg%    3.661007  5.692555e-02     0.028035
# 14          ftr   11.850251  6.833223e-04     0.000766
# 15          3pr    9.709723  2.063094e-03     0.055318
# 16      %pts_ft    0.093309  7.602849e-01     0.016510
# 20         drb%    0.345870  5.570302e-01     0.002396
# 21         trb%   30.761386  7.892812e-08     0.086209
# 23         tov%    7.037189  8.532347e-03     0.005520
# 24      ast_tov    5.282141  2.243175e-02     0.033665
# 25         stl%    4.879071  2.815820e-02     0.025383
# 26         blk%    6.516632  1.132610e-02     0.024187
# 27          pf%    1.625093  2.036529e-01     0.015358
# 28         pppd   26.944237  4.557127e-07     0.059229
# 29     opp_ppsa   27.400928  3.688404e-07     0.063624
# 30        efgd%   26.450702  5.730475e-07     0.055144
# 31         ftrd    3.288480  7.105418e-02     0.048761
# 32         3prd    0.772191  3.804453e-01     0.037776
# 34     %pts_2pd    0.047510  8.276449e-01     0.033800
# 37        tovd%    5.564029  1.915981e-02     0.029494
# 38  opp_ast_tov    7.728616  5.879236e-03     0.010368
# 39     opp_stl%    2.164315  1.425968e-01     0.006480
# 40     opp_blk%    1.770139  1.846656e-01     0.028108

# %%
feature_df = feature_df[feature_df['p_values'] < .05]
feature_df.sort_values(by='f_values', ascending=False)
# Out:
#         feature    f_values      p_values  mutual_info
# 10          rpi  129.354262  3.945765e-24     0.223487
# 7   hhs_net_rtg  107.005122  6.979264e-21     0.245777
# 9   hhs_def_rtg   84.269756  2.405636e-17     0.191677
# 8   hhs_off_rtg   61.517352  1.572748e-13     0.119482
# 2       net_ppg   45.572335  1.157757e-10     0.089978
# 5       net_rtg   43.605349  2.690247e-10     0.109977
# 4       def_rtg   32.793562  3.143704e-08     0.060184
# 21         trb%   30.761386  7.892812e-08     0.086209
# 29     opp_ppsa   27.400928  3.688404e-07     0.063624
# 28         pppd   26.944237  4.557127e-07     0.059229
# 30        efgd%   26.450702  5.730475e-07     0.055144
# 1       opp_ppg   20.136089  1.133581e-05     0.033082
# 14          ftr   11.850251  6.833223e-04     0.000766
# 15          3pr    9.709723  2.063094e-03     0.055318
# 3       off_rtg    9.010296  2.976932e-03     0.009751
# 38  opp_ast_tov    7.728616  5.879236e-03     0.010368
# 23         tov%    7.037189  8.532347e-03     0.005520
# 26         blk%    6.516632  1.132610e-02     0.024187
# 0           ppg    5.851772  1.632865e-02     0.014406
# 37        tovd%    5.564029  1.915981e-02     0.029494
# 24      ast_tov    5.282141  2.243175e-02     0.033665
# 25         stl%    4.879071  2.815820e-02     0.025383
# 12         ppsa    4.679716  3.153819e-02     0.015035
# 11          ppp    3.911691  4.912973e-02     0.011653

# %%
feature_df = feature_df[feature_df['f_values'] > 5]
feature_df.sort_values(by='f_values', ascending=False)
# Out:
#         feature    f_values      p_values  mutual_info
# 10          rpi  129.354262  3.945765e-24     0.223487
# 7   hhs_net_rtg  107.005122  6.979264e-21     0.245777
# 9   hhs_def_rtg   84.269756  2.405636e-17     0.191677
# 8   hhs_off_rtg   61.517352  1.572748e-13     0.119482
# 2       net_ppg   45.572335  1.157757e-10     0.089978
# 5       net_rtg   43.605349  2.690247e-10     0.109977
# 4       def_rtg   32.793562  3.143704e-08     0.060184
# 21         trb%   30.761386  7.892812e-08     0.086209
# 29     opp_ppsa   27.400928  3.688404e-07     0.063624
# 28         pppd   26.944237  4.557127e-07     0.059229
# 30        efgd%   26.450702  5.730475e-07     0.055144
# 1       opp_ppg   20.136089  1.133581e-05     0.033082
# 14          ftr   11.850251  6.833223e-04     0.000766
# 15          3pr    9.709723  2.063094e-03     0.055318
# 3       off_rtg    9.010296  2.976932e-03     0.009751
# 38  opp_ast_tov    7.728616  5.879236e-03     0.010368
# 23         tov%    7.037189  8.532347e-03     0.005520
# 26         blk%    6.516632  1.132610e-02     0.024187
# 0           ppg    5.851772  1.632865e-02     0.014406
# 37        tovd%    5.564029  1.915981e-02     0.029494
# 24      ast_tov    5.282141  2.243175e-02     0.033665

# %% [markdown]
# ## II. Wrapper Methods

# %% [markdown]
# ### A. Forward Selection

# %%
# Normalize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Forward Selection using AIC
def forward_selection_logistic_aic(X_train, y_train, X_test, y_test):
    selected_features = []
    remaining_features = list(X_train.columns)  # Column names
    best_f1_train = 0
    best_f1_test = 0
    best_aic = np.inf  # Start with a large AIC value
    
    while remaining_features:
        aic_list = []
        f1_train_list = []
        f1_test_list = []
        
        for feature in remaining_features:
            current_features = selected_features + [feature]
            X_train_subset = X_train[current_features]
            X_test_subset = X_test[current_features]
            
            # Add constant for intercept (statsmodels requires constant)
            X_train_subset_sm = sm.add_constant(X_train_subset)
            X_test_subset_sm = sm.add_constant(X_test_subset)
            
            # Fit the logistic regression model using statsmodels (to compute AIC)
            model = sm.Logit(y_train, X_train_subset_sm)
            result = model.fit()
            
            aic = result.aic  # Extract AIC value
            aic_list.append(aic)
            
            # Now, use sklearn for F1 score calculation
            log_reg_model = LogisticRegression(solver='liblinear')
            log_reg_model.fit(X_train_subset, y_train)  # Fit model without constant term
            
            # Make predictions on both train and test data
            y_train_pred = log_reg_model.predict(X_train_subset)
            y_test_pred = log_reg_model.predict(X_test_subset)
            
            # Calculate F1 scores
            f1_train = f1_score(y_train, y_train_pred)
            f1_test = f1_score(y_test, y_test_pred)
            
            f1_train_list.append(f1_train)
            f1_test_list.append(f1_test)
        
        # Select the feature that gives the lowest AIC
        best_feature_idx = np.argmin(aic_list)
        selected_features.append(remaining_features[best_feature_idx])
        remaining_features.remove(remaining_features[best_feature_idx])
        
        best_aic = aic_list[best_feature_idx]
        best_f1_train = f1_train_list[best_feature_idx]
        best_f1_test = f1_test_list[best_feature_idx]
        
    return selected_features, best_aic, best_f1_train, best_f1_test

# Perform forward selection using AIC
selected_features, best_aic, best_f1_train, best_f1_test = forward_selection_logistic_aic(
    X_train, y_train, X_test, y_test
)

# Output the results
print("Selected Features:", selected_features)
print("Best AIC:", best_aic)
print("Best F1 Score on Training Set:", best_f1_train)
print("Best F1 Score on Test Set:", best_f1_test)

# Create the final Logistic Regression model using selected features
log_reg_final = LogisticRegression(solver='liblinear')
X_train_final = X_train[selected_features]
X_test_final = X_test[selected_features]

# Fit the final model
log_reg_final.fit(X_train_final, y_train)

# Make predictions on training and testing sets
y_train_pred_final = log_reg_final.predict(X_train_final)
y_test_pred_final = log_reg_final.predict(X_test_final)

# Evaluate using F1 score
final_f1_train = f1_score(y_train, y_train_pred_final)
final_f1_test = f1_score(y_test, y_test_pred_final)

print("Final F1 Score on Training Set:", final_f1_train)
print("Final F1 Score on Test Set:", final_f1_test)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.592751
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564486
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.507423
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.586014
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.538385
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.511422
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597908
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.378846
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.478644
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.436548
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.351039
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.596925
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595213
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597438
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580711
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584989
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605159
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.603518
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592973
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605289
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.604617
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.543874
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597725
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590366
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594070
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595050
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.591148
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601875
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.549780
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.548504
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.550737
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.598353
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.603699
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605060
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605257
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602815
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601983
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593651
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589020
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600722
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601586
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.350942
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.351028
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350774
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350239
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.348902
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350636
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.349616
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.344203
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.351039
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.344079
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.349952
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350505
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350476
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.347409
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.348162
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.348382
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.347223
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.342209
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.345313
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350329
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.349887
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.351033
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.349404
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.348771
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350563
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350735
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.348790
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.348727
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350916
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350831
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.348697
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.347997
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337986
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350878
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.340881
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350428
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350840
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.348467
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.350859
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.351006
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.351030
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337820
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337957
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337481
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337294
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335562
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337410
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337479
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.331326
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337971
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.330511
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337093
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337614
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337518
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335141
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335702
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335232
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.332985
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325113
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.332293
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337577
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337159
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337866
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.336498
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335508
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337980
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337023
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335774
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335478
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337845
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337734
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.334743
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.335598
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337773
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.327467
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337143
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337980
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.336822
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337878
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337973
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.337984
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324745
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325099
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324779
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324800
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323853
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324776
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324575
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.319262
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325065
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.319849
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324533
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324498
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324621
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323233
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.322530
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323253
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324224
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.319224
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325043
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323301
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324830
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324473
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323155
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325081
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324202
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323229
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323733
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325087
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325104
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.322527
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323892
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325064
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316569
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323898
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325105
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.323716
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325053
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.325113
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.324842
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316515
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316557
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316393
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315359
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.314465
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316355
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315496
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.310873
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316492
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.309463
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315184
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315619
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315846
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315925
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.313694
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.313216
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.314867
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.311233
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316546
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315098
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316173
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316143
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315429
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316371
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315663
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.313914
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.314660
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316564
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316560
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.313835
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315506
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306892
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315680
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316563
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315458
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316389
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316543
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.315358
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306742
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306887
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306767
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306114
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305505
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306714
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306142
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.301420
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306882
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.301625
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305786
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306160
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306485
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306314
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.303881
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300759
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305153
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.301727
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306882
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306421
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305993
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306612
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305684
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306525
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306368
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.304618
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305928
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306725
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306680
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305149
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306595
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305769
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306827
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.305384
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306581
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306597
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.306005
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300521
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300721
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300658
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300208
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299521
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300550
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299592
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293694
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300613
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.294986
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300059
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300247
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300397
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299045
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.298461
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299929
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.295212
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300713
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300193
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299580
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300306
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.298157
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299391
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300390
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.298734
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299816
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300688
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300625
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299275
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300353
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.299800
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300003
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.298006
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300596
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300754
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.300429
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293692
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.291314
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.283155
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.290355
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293586
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.284313
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292790
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292916
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292873
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.291189
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292066
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292343
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293110
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.291583
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293027
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.289426
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293691
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.290485
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292035
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293620
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292644
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292999
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293556
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.291404
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293544
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.291057
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.290944
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292891
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293679
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293293
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293482
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.292929
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293307
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293383
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.293049
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282633
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282654
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281868
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281702
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.283102
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282919
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281496
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281440
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282129
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281990
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282226
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282947
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281363
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282186
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277359
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.283155
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.280818
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281594
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.283133
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282799
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.283031
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.283155
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.280600
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282343
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282774
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282872
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281411
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282496
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.281337
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.283120
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282118
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282223
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282809
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.282536
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277237
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277247
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.275212
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.274910
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277266
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277255
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.274535
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.274466
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.274595
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272697
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.273285
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277167
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.273112
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.276346
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277322
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.275130
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.275588
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.276468
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277359
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277354
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277324
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.274162
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.275970
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277078
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277175
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.275312
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.276835
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.275328
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.276870
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.276984
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.274235
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277306
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.277018
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.264346
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264461
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.272626
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272692
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272251
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272389
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272677
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272669
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272535
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272581
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272619
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.271175
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.271548
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272696
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.271546
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.268662
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.271614
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272541
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272569
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272097
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.269654
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272415
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.269714
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.269895
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.271595
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272596
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.271473
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272613
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272270
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.269805
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.271677
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272579
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.262492
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.261269
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.259851
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263666
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263811
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258385
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258295
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.262716
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264308
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263715
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.262644
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.261429
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264278
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264089
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.259100
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263827
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263785
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264332
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264157
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.259659
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263566
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263674
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263670
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.262239
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264322
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264080
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264051
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264346
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.261988
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.263060
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.264345
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.256098
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258009
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258293
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257479
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257815
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257913
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257788
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258073
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258145
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257213
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.255695
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258279
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258026
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.249303
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.255803
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257654
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258203
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257372
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.254535
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257328
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.254429
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.254087
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.257511
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.256796
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258246
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258193
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258295
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.252815
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.256331
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.258114
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.248604
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.248838
#          Iterations 9
# Optimization terminated successfully.
# ...
#          Current function value: 0.207165
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207235
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206873
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207305
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206912
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206180
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207086
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207120
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207181
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207308
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207320
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207199
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206412
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205985
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205596
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205903
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206083
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206070
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206079
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206120
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206095
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205759
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205816
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205958
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205896
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206124
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.206177
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202730
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205860
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202374
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.201457
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202080
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202556
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202660
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.201819
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202663
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202645
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202508
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202467
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200816
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202599
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202709
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202691
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.202413
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200815
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200670
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200438
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200744
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200797
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200815
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200796
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200536
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200660
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200544
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200813
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200715
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200453
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200772
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200277
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200364
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200330
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200420
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200217
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200388
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200172
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200299
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200241
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200434
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200246
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200192
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200308
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200067
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200134
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200138
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200161
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199912
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200152
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200027
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200018
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200162
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200107
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199959
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.200041
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199890
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199912
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199864
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199911
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199850
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199821
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199804
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199911
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199856
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199755
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199841
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199720
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199752
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199708
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199755
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199705
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199652
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199739
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199753
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199697
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199593
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199541
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199585
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199554
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199593
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198813
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199476
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199593
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199575
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199577
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198704
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198776
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198805
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198791
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198749
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198813
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198813
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198803
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.190472
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.198697
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198679
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198640
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198701
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198704
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.198672
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.190428
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190459
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190422
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190459
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190339
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190289
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190238
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190287
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190263
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190287
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190133
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190007
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190133
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190111
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190133
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190005
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.189985
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.190006
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.189985
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.189984
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.189984
#          Iterations 11
# Selected Features: ['rpi', '%pts_ftd', '%pts_3p', '%pts_3pd', '%pts_2pd', '%pts_ft', 'hhs_net_rtg', 'net_ppg', 'orb%', 'ppsa', 'ppg', 'hhs_def_rtg', 'ast%', '3pr', 'opp_blk%', '%pts_2p', 'opp_ppg', 'pf%', 'ftrd', 'trb%', 'efg%', 'astd%', 'opp_ppsa', 'stl%', 'tovd%', 'ast_tov', 'opp_stl%', 'pppd', 'net_rtg', 'drb%', 'ppp', 'opp_ast_tov', 'opp_pf%', 'ftr', 'off_rtg', 'def_rtg', '3prd', 'efgd%', 'pace', 'tov%', 'blk%', 'hhs_off_rtg']
# Best AIC: 175.2926334873968
# Best F1 Score on Training Set: 0.8888888888888888
# Best F1 Score on Test Set: 0.8993288590604027
# Final F1 Score on Training Set: 0.8888888888888888
# Final F1 Score on Test Set: 0.8993288590604027

# %%
len(selected_features)
# Out:
# 42

# %% [markdown]
# ### B. Recursive Feature Elimination

# %%
# Convert scaled data back to DataFrame to keep track of column names
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# Create a Logistic Regression model
log_reg = LogisticRegression(solver='liblinear')

# Initialize RFE with logistic regression as the model and the number of features to select
rfe = RFE(estimator=log_reg, n_features_to_select=12)  # Select top 12 features

# Fit RFE on the scaled training data
rfe.fit(X_train_scaled, y_train)

# Get the selected features (column names)
selected_features = X_train_scaled.columns[rfe.support_]
print("Selected Features:", selected_features)

# Train a logistic regression model using only the selected features
log_reg.fit(X_train_scaled[selected_features], y_train)

# Make predictions on both training and testing datasets
y_train_pred = log_reg.predict(X_train_scaled[selected_features])
y_test_pred = log_reg.predict(X_test_scaled[selected_features])

# Evaluate the F1 score on both training and testing datasets
f1_train = f1_score(y_train, y_train_pred)
f1_test = f1_score(y_test, y_test_pred)

# Output the results
print("F1 Score on Training Set:", f1_train)
print("F1 Score on Test Set:", f1_test)
# Out:
# Selected Features: Index(['opp_ppg', 'hhs_net_rtg', 'hhs_def_rtg', 'rpi', 'efg%', '3pr',
#        '%pts_3p', 'orb%', 'ast%', '%pts_ftd', '%pts_2pd', '%pts_3pd'],
#       dtype='object')
# F1 Score on Training Set: 0.9194029850746269
# F1 Score on Test Set: 0.8933333333333332

# %% [markdown]
# ### C. Lasso Regression

# %%
# Create a Lasso Logistic Regression model (penalty='l1' for Lasso)
lasso_log_reg = LogisticRegression(solver='liblinear', penalty='l1', max_iter=1000)

# Fit the model on the training data
lasso_log_reg.fit(X_train_scaled, y_train)

# Make predictions on both training and testing datasets
y_train_pred = lasso_log_reg.predict(X_train_scaled)
y_test_pred = lasso_log_reg.predict(X_test_scaled)

# Evaluate the F1 score on both training and testing datasets
f1_train = f1_score(y_train, y_train_pred)
f1_test = f1_score(y_test, y_test_pred)

# Output the results
print("F1 Score on Training Set:", f1_train)
print("F1 Score on Test Set:", f1_test)

# Get the non-zero coefficients (selected features) from the Lasso model
selected_features = X.columns[(lasso_log_reg.coef_ != 0).flatten()]
print("Selected Features (Columns used in the model):", selected_features)
# Out:
# F1 Score on Training Set: 0.9285714285714286
# F1 Score on Test Set: 0.8648648648648649
# Selected Features (Columns used in the model): Index(['opp_ppg', 'pace', 'hhs_net_rtg', 'hhs_def_rtg', 'rpi', 'efg%', 'ftr',
#        '3pr', '%pts_ft', '%pts_2p', '%pts_3p', 'orb%', 'trb%', 'ast%',
#        'ast_tov', 'stl%', 'pf%', 'opp_ppsa', 'efgd%', '3prd', '%pts_ftd',
#        '%pts_2pd', '%pts_3pd', 'astd%', 'opp_stl%', 'opp_blk%'],
#       dtype='object')

# %%
len(selected_features)
# Out:
# 26

# %% [markdown]
# ## III. Tree Methods

# %% [markdown]
# ### A. Decision Tree Information Gain

# %%
X_train_scaled = scaler.fit_transform(X_train)  # Scaled training features
X_test_scaled = scaler.transform(X_test)  # Scaled test features

# Create a Decision Tree Classifier model
decision_tree = DecisionTreeClassifier(random_state=42)

# Fit the model on the training data
decision_tree.fit(X_train_scaled, y_train)

# Make predictions on both training and testing datasets
y_train_pred = decision_tree.predict(X_train_scaled)
y_test_pred = decision_tree.predict(X_test_scaled)

# Evaluate the F1 score on both training and testing datasets
f1_train = f1_score(y_train, y_train_pred)
f1_test = f1_score(y_test, y_test_pred)

# Output the F1 scores
print("F1 Score on Training Set:", f1_train)
print("F1 Score on Test Set:", f1_test)

# Get feature importances (information gain)
feature_importances = decision_tree.feature_importances_

# Get the selected features based on their importance (non-zero importance)
selected_features = X.columns[feature_importances > 0]
print("Selected Features (Columns used in the model):", selected_features)
# Out:
# F1 Score on Training Set: 1.0
# F1 Score on Test Set: 0.8513513513513513
# Selected Features (Columns used in the model): Index(['opp_ppg', 'net_ppg', 'pace', 'hhs_net_rtg', 'rpi', 'ftr', 'orb%',
#        'ast%', 'stl%', 'blk%', '%pts_ftd', '%pts_2pd', 'astd%', 'tovd%',
#        'opp_blk%'],
#       dtype='object')

# %%
len(selected_features)
# Out:
# 15

# %% [markdown]
# ### B. Random Forest

# %%
# Create a Random Forest Classifier model
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)

# Fit the model on the training data
random_forest.fit(X_train_scaled, y_train)

# Make predictions on both training and testing datasets
y_train_pred = random_forest.predict(X_train_scaled)
y_test_pred = random_forest.predict(X_test_scaled)

# Evaluate the F1 score on both training and testing datasets
f1_train = f1_score(y_train, y_train_pred)
f1_test = f1_score(y_test, y_test_pred)

# Output the F1 scores
print("F1 Score on Training Set:", f1_train)
print("F1 Score on Test Set:", f1_test)

# Get feature importances (information gain)
feature_importances = random_forest.feature_importances_

# Get the columns (features) that were selected (those with non-zero importance)
selected_features = X.columns[feature_importances > .02]
print("Selected Features (Columns used in the model):", selected_features)
# Out:
# F1 Score on Training Set: 1.0
# F1 Score on Test Set: 0.9019607843137255
# Selected Features (Columns used in the model): Index(['opp_ppg', 'net_ppg', 'net_rtg', 'hhs_net_rtg', 'hhs_off_rtg',
#        'hhs_def_rtg', 'rpi', '3pr', 'trb%'],
#       dtype='object')

# %%
len(selected_features)
# Out:
# 9

# %% [markdown]
# ### C. Extra Tree

# %%
# Create an Extra Trees Classifier model
extra_trees = ExtraTreesClassifier(n_estimators=100, random_state=42)

# Fit the model on the training data
extra_trees.fit(X_train_scaled, y_train)

# Make predictions on both training and testing datasets
y_train_pred = extra_trees.predict(X_train_scaled)
y_test_pred = extra_trees.predict(X_test_scaled)

# Evaluate the F1 score on both training and testing datasets
f1_train = f1_score(y_train, y_train_pred)
f1_test = f1_score(y_test, y_test_pred)

# Output the F1 scores
print("F1 Score on Training Set:", f1_train)
print("F1 Score on Test Set:", f1_test)

# Get feature importances (information gain)
feature_importances = extra_trees.feature_importances_
# Out:
# F1 Score on Training Set: 1.0
# F1 Score on Test Set: 0.9182389937106917

# %%
column_names = X_train.columns
tree_df = pd.DataFrame({
    'feature': column_names,
    'importance': feature_importances
})
tree_df
#tree_df.to_csv('tree.csv')
# Out:
#         feature  importance
# 0           ppg    0.013682
# 1       opp_ppg    0.018359
# 2       net_ppg    0.024426
# 3       off_rtg    0.015297
# 4       def_rtg    0.019519
# 5       net_rtg    0.028614
# 6          pace    0.014979
# 7   hhs_net_rtg    0.092660
# 8   hhs_off_rtg    0.049906
# 9   hhs_def_rtg    0.065346
# 10          rpi    0.105365
# 11          ppp    0.012436
# 12         ppsa    0.014124
# 13         efg%    0.013060
# 14          ftr    0.017601
# 15          3pr    0.026051
# 16      %pts_ft    0.014786
# 17      %pts_2p    0.019426
# 18      %pts_3p    0.023137
# 19         orb%    0.015916
# 20         drb%    0.019881
# 21         trb%    0.024748
# 22         ast%    0.019273
# 23         tov%    0.019638
# 24      ast_tov    0.019457
# 25         stl%    0.020364
# 26         blk%    0.016346
# 27          pf%    0.017245
# 28         pppd    0.019019
# 29     opp_ppsa    0.019619
# 30        efgd%    0.020049
# 31         ftrd    0.015300
# 32         3prd    0.015675
# 33     %pts_ftd    0.019008
# 34     %pts_2pd    0.017627
# 35     %pts_3pd    0.014258
# 36        astd%    0.016300
# 37        tovd%    0.016785
# 38  opp_ast_tov    0.014569
# 39     opp_stl%    0.016790
# 40     opp_blk%    0.017233
# 41      opp_pf%    0.016125

# %% [markdown]
# ## IV. Exhaustive Feature Selection

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

X_train_scaled2 = X_train_scaled[[
'opp_ppg', 'hhs_net_rtg', 'hhs_def_rtg', 'rpi', 'ppsa', '3pr',
       '%pts_3p', 'orb%', 'ast%', '%pts_ftd', '%pts_2pd', '%pts_3pd',
        'pppd', 'hhs_off_rtg', 'net_ppg', 'ftr', 'astd%', 'tovd%'
]]

X_test_scaled2 = X_test_scaled[[
'opp_ppg', 'hhs_net_rtg', 'hhs_def_rtg', 'rpi', 'ppsa', '3pr',
       '%pts_3p', 'orb%', 'ast%', '%pts_ftd', '%pts_2pd', '%pts_3pd',
        'pppd', 'hhs_off_rtg', 'net_ppg', 'ftr', 'astd%', 'tovd%'
]]

# %%
# Initialize variables to track the best model
best_f1 = 0
best_features = []
best_train_f1 = 0

# Iterate over all possible subsets of features
for k in range(1, len(X_train_scaled2.columns) + 1):
    for subset in combinations(X_train_scaled2.columns, k):
        X_train_subset = X_train_scaled2[list(subset)]
        X_test_subset = X_test_scaled2[list(subset)]
        
        # Train the model with the subset of features
        log_reg.fit(X_train_subset, y_train)
        
        # Make predictions on the test set
        y_test_pred = log_reg.predict(X_test_subset)
        test_f1 = f1_score(y_test, y_test_pred)
        
        # Make predictions on the training set
        y_train_pred = log_reg.predict(X_train_subset)
        train_f1 = f1_score(y_train, y_train_pred)
        
        # Track the best subset based on test F1 score
        if test_f1 > best_f1:
            best_f1 = test_f1
            best_features = subset
            best_train_f1 = train_f1

# Output the best feature subset and the F1 scores
print(f"Best Feature Subset: {best_features}")
print(f"Best Test F1 Score: {best_f1:.4f}")
print(f"Training F1 Score of Best Model: {best_train_f1:.4f}")
# Out:
# Best Feature Subset: ('hhs_net_rtg', '3pr', '%pts_3p', '%pts_3pd', 'pppd', 'hhs_off_rtg', 'net_ppg')
# Best Test F1 Score: 0.9427
# Training F1 Score of Best Model: 0.8968

# %% [raw]
# df.columns

# %%
lasso_df = df[['game_id', 'year', 'round', 'region', 'high_team_id', 'low_team_id', 'win', 
               'opp_ppg', 'hhs_net_rtg', 'hhs_def_rtg', 'rpi', 'efg%', '3pr',
               '%pts_3p', 'orb%', 'ast%', '%pts_ftd', '%pts_2pd', '%pts_3pd']]
lasso_df.to_csv('lasso_first_weekend.csv')
forest_df = df[['game_id', 'year', 'round', 'region', 'high_team_id', 'low_team_id', 'win', 
               'opp_ppg', 'net_ppg', 'net_rtg', 'hhs_net_rtg', 'hhs_off_rtg',
               'hhs_def_rtg', 'rpi', '3pr', 'trb%']]
forest_df.to_csv('forest_first_weekend.csv')

# %% [raw]
# exhaustive_df = df[['game_id', 'year', 'round', 'region', 'high_team_id', 'low_team_id', 'win',
#                'hhs_net_rtg', 'hhs_def_rtg', 'net_ppg', '3pr', 'opp_ast_tov', '%pts_3p']]
# exhaustive_df.to_csv('exhaustive_first_weekend.csv')

# %%
exhaustive_df = df[['game_id', 'year', 'round', 'region', 'high_team_id', 'low_team_id', 'win', 
               'hhs_net_rtg', '3pr', '%pts_3p', '%pts_3pd', 'pppd', 'hhs_off_rtg', 'net_ppg']]
exhaustive_df.to_csv('exhaustive_first_weekend2.csv')
