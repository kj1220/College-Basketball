# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('womens_matchups.csv')
print(df.shape)
df.head()
# Out:
# (252, 27)
#    year region         round  high_bracket_seed   high_team_id  \
# 0  2021   East   First Round                  1  2021 Stanford
# 1  2021   East  Second Round                  1  2021 Stanford
# 2  2021   East      Sweet 16                  1  2021 Stanford
# 3  2021   East   Elite Eight                  1  2021 Stanford
# 4  2021   East      Sweet 16                  6    2021 Oregon
#
#    low_bracket_seed        low_team_id  win  adj_oe  adj_de  ...  ftr  ftrd  \
# 0                16   2021 Utah Valley    1    15.9    40.3  ... -0.4  -6.1
# 1                 8  2021 Oklahoma St.    1     0.9    25.5  ... -0.3   1.8
# 2                 5  2021 Missouri St.    1     2.0    26.6  ... -7.2  -2.3
# 3                 2    2021 Louisville    1     3.8    13.3  ... -8.9   3.1
# 4                 2    2021 Louisville    0    -3.3     3.4  ... -9.7   3.2
#
#     2p%  2p%d  3p%  3p%d  3pr  3prd  adj_tempo   wab
# 0  11.0 -10.9  5.4  -3.9  3.4   0.3        4.9  17.0
# ...

# %%
sns.boxplot(x='barthag', y='round', data=df)
# Out:
# <Axes: xlabel='barthag', ylabel='round'>

# %%
sns.boxplot(x='wab', y='round', data=df)
# Out:
# <Axes: xlabel='wab', ylabel='round'>

# %%
sns.boxplot(x='adj_oe', y='round', data=df)
# Out:
# <Axes: xlabel='adj_oe', ylabel='round'>

# %%
sns.boxplot(x='adj_de', y='round', data=df)
# Out:
# <Axes: xlabel='adj_de', ylabel='round'>
