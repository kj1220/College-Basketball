# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('matchups_20.csv')
print(df.shape)
df.head()
# Out:
# (1258, 35)
#    year region         round  high_bracket_seed    high_bracket_team  \
# 0  2004   East   First Round                  1  2004 Saint Joseph's
# 1  2004   East  Second Round                  1  2004 Saint Joseph's
# 2  2004   East      Sweet 16                  1  2004 Saint Joseph's
# 3  2004   East  Second Round                 12       2004 Manhattan
# 4  2004   East   Elite Eight                  1  2004 Saint Joseph's
#
#    low_bracket_seed   low_bracket_team  win  kenpom_adjem  kenpom_adjoe  ...  \
# 0                16       2004 Liberty    1      30.51285       89.1570  ...
# 1                 8    2004 Texas Tech    1      11.71310       82.5819  ...
# 2                 4   2004 Wake Forest    1       5.43710       86.9808  ...
# 3                 4   2004 Wake Forest    0     -10.75180       76.1598  ...
# 4                 2  2004 Oklahoma St.    0       3.01610       81.0911  ...
#
#    off_ft_pct  off_block_pct  def_2pt_pct  def_3pt_pct  def_ft_pct  \
# ...

# %%
df.columns.to_list()
# Out:
# ['year',
#  'region',
#  'round',
#  'high_bracket_seed',
#  'high_bracket_team',
#  'low_bracket_seed',
#  'low_bracket_team',
#  'win',
#  'kenpom_adjem',
#  'kenpom_adjoe',
#  'kenpom_adjde',
#  'off_eff',
#  'def_eff',
#  'tempo',
#  'adj_tempo',
#  'off_efg_pct',
#  'off_to_pct',
#  'off_or_pct',
#  'off_ft_rate',
#  'def_efg_pct',
#  'def_to_pct',
#  'def_or_pct',
#  'def_ft_rate',
#  'off_2pt_pct',
#  'off_3pt_pct',
#  'off_ft_pct',
#  'off_block_pct',
#  'def_2pt_pct',
#  'def_3pt_pct',
#  'def_ft_pct',
#  'def_block_pct',
#  'off_ast_rate',
#  'off_stl_rate',
#  'def_ast_rate',
#  'def_stl_rate']

# %%
sns.boxplot(x='kenpom_adjem', y='round', data=df)
# Out:
# <Axes: xlabel='kenpom_adjem', ylabel='round'>

# %%
sns.boxplot(x='kenpom_adjoe', y='round', data=df)
# Out:
# <Axes: xlabel='kenpom_adjoe', ylabel='round'>

# %%
sns.boxplot(x='kenpom_adjde', y='round', data=df)
# Out:
# <Axes: xlabel='kenpom_adjde', ylabel='round'>

# %%
sns.boxplot(x='off_eff', y='round', data=df)
# Out:
# <Axes: xlabel='off_eff', ylabel='round'>

# %%
sns.boxplot(x='def_eff', y='round', data=df)
# Out:
# <Axes: xlabel='def_eff', ylabel='round'>

# %%
sns.boxplot(x='tempo', y='round', data=df)
# Out:
# <Axes: xlabel='tempo', ylabel='round'>

# %%
sns.boxplot(x='adj_tempo', y='round', data=df)
# Out:
# <Axes: xlabel='adj_tempo', ylabel='round'>

# %%
sns.boxplot(x='off_efg_pct', y='round', data=df)
# Out:
# <Axes: xlabel='off_efg_pct', ylabel='round'>

# %%
sns.boxplot(x='off_to_pct', y='round', data=df)
# Out:
# <Axes: xlabel='off_to_pct', ylabel='round'>
